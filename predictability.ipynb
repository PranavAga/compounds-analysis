# %% [markdown]
# _S25: Computational Psycholinguistics_
#
# **Team Project**
#
# Swarang Joshi, 2022114010
#
# Pranav Agarwal, 2021113018
#
# # Compund Analysis: Compound Predictability

# %%
import pandas as pd
from scipy.stats import spearmanr
from matplotlib import pyplot as plt
from sklearn.linear_model import Lasso

# %% [markdown]
# ## Loading the Data

# %%
# Load the CSV data
ladec_df = pd.read_csv('data/LADECv1-2019.csv')
ladec_df.head()
# Out:
#    id_master     c1     c2        stim  obs  obsc1  obsc2  stimlen  c1len  \
# 0       3237    gad  about    gadabout    1      4      3        8      3
# 1       4592  knock  about  knockabout    1      3      4       10      5
# 2       8231   turn  about   turnabout    1     19      7        9      4
# 3       6139   race  about   raceabout    1      4      1        9      4
# 4       8331   walk  about   walkabout    1      2      5        9      4
#
#    c2len  ...  Juhasz_tran st_c1_mean  st_c2_mean  Zipfvalue  c1_SLlg10wf  \
# 0      5  ...          NaN        NaN         NaN   1.768955       1.4314
# 1      5  ...          NaN        NaN         NaN   1.592864       3.5185
# 2      5  ...          NaN      4.452       2.813   2.333227       4.1940
# 3      5  ...          NaN        NaN         NaN        NaN       3.4994
# 4      5  ...          NaN      4.594       2.733   2.246077       4.0418
#
#    c2_SLlg10wf  c1_BLPbncfrequency  c1_BLPbncfrequencymillion  \
# ...

# %%
# Load the CSV data
compounds_glove_df = pd.read_csv("./data/compounds_glove.csv")
compounds_glove_df.head()
# Out:
#       Compound   left   right      TRAN       LMD  glove_LMD  glove_TRAN
# 0  aboveground  above  ground  6.200000  4.000000   5.176486    0.879524
# 1      airbase    air    base  4.266667  5.866667   5.454429    3.403150
# 2     airborne    air   borne  3.857143  3.133333   4.191957    2.894971
# 3     aircraft    air   craft  4.533333  4.266667   4.360665    4.090656
# 4     airfield    air   field  4.333333  5.714286   4.356041    2.900640

# %%
# Find the index of the rows which dont have a pair of words in the LADEC dataset
absent_pairs = []

for index, row in compounds_glove_df.iterrows():
    if (row['Compound'] not in ladec_df['stim'].values) or (ladec_df[ladec_df['stim'] == row['Compound']]['ratingcmp'].isnull().values[0]):
        absent_pairs.append(index)
    else:
        compounds_glove_df.loc[index, 'pred'] = ladec_df[ladec_df['stim'] == row['Compound']]['ratingcmp'].values[0]

print(f"Number of absent pairs: {len(absent_pairs)}")
# Out:
# Number of absent pairs: 171

# %%
# Drop the absent pairs from the dataframe
compounds_glove_df = compounds_glove_df.drop(absent_pairs)
compounds_glove_df = compounds_glove_df.reset_index(drop=True)
compounds_glove_df
# Out:
#        Compound   left  right      TRAN       LMD  glove_LMD  glove_TRAN  \
# 0      aircraft    air  craft  4.533333  4.266667   4.360665    4.090656
# 1      airfield    air  field  4.333333  5.714286   4.356041    2.900640
# 2       airflow    air   flow  6.000000  4.866667   6.039343    2.757553
# 3       airlift    air   lift  5.333333  5.533333   4.110052    2.689244
# 4       airline    air   line  3.071429  3.333333   3.432917    2.995321
# ..          ...    ...    ...       ...       ...        ...         ...
# 447   womankind  woman   kind  3.928571  2.066667   4.760577    0.462640
# 448    wordplay   word   play  4.928571  3.533333   4.075371    1.622669
# 449  wristwatch  wrist  watch  6.266667  6.333333   4.221955    2.503287
# 450   yardstick  yards   tick  5.866667  5.333333   5.442741    1.236868
# 451    yearbook   year   book  5.384615  5.933333   5.478864    1.846408
#
#           pred
# 0    61.333332
# 1    57.340908
# 2    81.837837
# 3    64.074997
# ...

# %% [markdown]
# ## Correlation

# %%
# Finding Spearman correlation between the predictability and LMD and ST
corr_lmd = spearmanr(compounds_glove_df['pred'], compounds_glove_df['LMD'])
corr_st = spearmanr(compounds_glove_df['pred'], compounds_glove_df['TRAN'])

corr_lmd_glove = spearmanr(compounds_glove_df['pred'], compounds_glove_df['glove_LMD'])
corr_st_glove = spearmanr(compounds_glove_df['pred'], compounds_glove_df['glove_TRAN'])

print(f"Spearman correlation between predictability")
print(f"\tand LMD:\t{corr_lmd[0]:.4f}, p-value: {corr_lmd[1]:.4f}")
print(f"\tand ST:\t{corr_st[0]:.4f}, p-value: {corr_st[1]:.4f}")
print(f"\tand LMD (Glove):\t{corr_lmd_glove[0]:.4f}, p-value: {corr_lmd_glove[1]:.4f}")
print(f"\tand ST (Glove):\t{corr_st_glove[0]:.4f}, p-value: {corr_st_glove[1]:.4f}")
# Out:
# Spearman correlation between predictability
# 	and LMD:	-0.1575, p-value: 0.0008
# 	and ST:	0.7326, p-value: 0.0000
# 	and LMD (Glove):	-0.0657, p-value: 0.1632
# 	and ST (Glove):	0.3096, p-value: 0.0000

# %%
# Plot mean RT vs model predictions
n_bars = 2
width = 0.6 - n_bars * 0.1
lmd_values = [corr_lmd[0], corr_lmd_glove[0]]
st_values = [corr_st[0], corr_st_glove[0]]

plt.figure(figsize=(5, 5))
plt.bar(range(n_bars), lmd_values, width=width, color='royalblue', label='LMD')
for i, v in enumerate(lmd_values):
    plt.text(i, v + 0.0005, f"{v:.4f}", ha='center', va='bottom')
plt.bar([x + width for x in range(n_bars)], st_values, width=width, color='orange', label='ST')
for i, v in enumerate(st_values):
    plt.text(i + width, v + 0.0005, f"{v:.4f}", ha='center', va='bottom')
plt.xticks([x + width / 2 for x in range(n_bars)], ['Humans', 'GloVe'])
plt.grid(axis = 'y')
plt.ylabel('Spearman Correlation')
plt.title('Spearman Correlation between\nPredictability and Psycholinguistic Measures')
plt.legend()
plt.show()

# %% [markdown]
# ## Training Regressor Predicting LMD and ST

# %%
# Fitting Regressors 
train_set = compounds_glove_df.sample(frac=0.7, random_state=42)
test_set = compounds_glove_df.drop(train_set.index)

# %%
pred_lmd_model = Lasso()
pred_lmd_model.fit(train_set[['pred']], train_set['LMD'])

pred_st_model = Lasso()
pred_st_model.fit(train_set[['pred']], train_set['TRAN'])

pred_glove_lmd_model = Lasso()
pred_glove_lmd_model.fit(train_set[['pred']], train_set['glove_LMD'])

pred_glove_st_model = Lasso()
pred_glove_st_model.fit(train_set[['pred']], train_set['glove_TRAN'])
# Out:
# Lasso()

# %%
# Predict on the test set
# Get R^2 score for both models
lmd_r2 = pred_lmd_model.score(test_set[['pred']], test_set['LMD'])
st_r2 = pred_st_model.score(test_set[['pred']], test_set['TRAN'])
glove_lmd_r2 = pred_glove_lmd_model.score(test_set[['pred']], test_set['glove_LMD'])
glove_st_r2 = pred_glove_st_model.score(test_set[['pred']], test_set['glove_TRAN'])

# Get MAE for both models
lmd_mae = ((test_set['LMD'] - pred_lmd_model.predict(test_set[['pred']]))).abs().mean()
st_mae = ((test_set['TRAN'] - pred_st_model.predict(test_set[['pred']]))).abs().mean()
glove_lmd_mae = ((test_set['glove_LMD'] - pred_glove_lmd_model.predict(test_set[['pred']]))).abs().mean()
glove_st_mae = ((test_set['glove_TRAN'] - pred_glove_st_model.predict(test_set[['pred']]))).abs().mean()

# %%
# Plot R^2 and MAE in 2 plots and add the values as labels
judges = ['Humans', 'GloVe']
n_bars = 2
width = 0.6 - n_bars * 0.1

plt.figure(figsize=(10,5))
plt.suptitle('Predictability Rating for Prediction', fontsize=16)

#   R^2
plt.subplot(1, 2, 1)
plt.bar(range(n_bars), [lmd_r2, glove_lmd_r2], width=width, color='royalblue', label='LMD')
for i, v in enumerate([lmd_r2, glove_lmd_r2]):
    plt.text(i, v + 0.0005, f"{v:.4f}", ha='center', va='bottom')
plt.bar([x + width for x in range(n_bars)], [st_r2, glove_st_r2], width=width, color='orange', label='ST')
for i, v in enumerate([st_r2, glove_st_r2]):
    plt.text(i + width, v + 0.0005, f"{v:.4f}", ha='center', va='bottom')
plt.xticks([x + width / 2 for x in range(n_bars)], ['Humans', 'GloVe'])
plt.grid(axis = 'y')
plt.ylabel(r'$R^2$')
plt.title(r'$R^2$ score of the regressor models')
plt.legend()

#   MAE
plt.subplot(1, 2, 2)
plt.bar(range(n_bars), [lmd_mae, glove_lmd_mae], width=width, color='royalblue', label='LMD')
for i, v in enumerate([lmd_mae, glove_lmd_mae]):
    plt.text(i, v + 0.0005, f"{v:.4f}", ha='center', va='bottom')
plt.bar([x + width for x in range(n_bars)], [st_mae, glove_st_mae], width=width, color='orange', label='ST')
for i, v in enumerate([st_mae, glove_st_mae]):
    plt.text(i + width, v + 0.0005, f"{v:.4f}", ha='center', va='bottom')
plt.xticks([x + width / 2 for x in range(n_bars)], ['Humans', 'GloVe'])
plt.grid(axis = 'y')
plt.ylabel(r'MAE')
plt.title(r'MAE score of the regressor models')
plt.legend()
plt.show()

# %% [markdown]
# ### Saving Regressor's results

# %%
# Predicting human judgements
predr_lmd_pred = pred_lmd_model.predict(
    compounds_glove_df[['pred']]
)
predr_st_pred = pred_st_model.predict(
    compounds_glove_df[['pred']]
)

# Predicting values from Glove embeddings
predr_glove_lmd_pred = pred_glove_lmd_model.predict(
    compounds_glove_df[['pred']]
)
predr_glove_st_pred = pred_glove_st_model.predict(
    compounds_glove_df[['pred']]
)

# %%
# Saving to a CSV file
predictions_df = pd.DataFrame(
    data={
        'Compound' : compounds_glove_df['Compound'].values,
        'left' : compounds_glove_df['left'].values,
        'right' : compounds_glove_df['right'].values,
        'predr_TRAN' : predr_st_pred,
        'predr_LMD' : predr_lmd_pred,
        'predr_glove_TRAN' : predr_glove_st_pred,
        'predr_glove_LMD' : predr_glove_lmd_pred
    }
)
predictions_df.head()
# Out:
#    Compound left  right  predr_TRAN  predr_LMD  predr_glove_TRAN  \
# 0  aircraft  air  craft    4.659537   5.321955          1.908295
# 1  airfield  air  field    4.499520   5.350417          1.876139
# 2   airflow  air   flow    5.481356   5.175776          2.073444
# 3   airlift  air   lift    4.769422   5.302409          1.930377
# 4   airline  air   line    3.944777   5.449090          1.764660
#
#    predr_glove_LMD
# 0         5.041603
# 1         5.041603
# 2         5.041603
# 3         5.041603
# 4         5.041603

# %%
predictions_df.to_csv('data/predictions/predictability.csv')
